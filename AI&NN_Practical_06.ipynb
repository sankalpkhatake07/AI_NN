# %% [markdown]
# ## Student Name: Aarti P. Kalyane
# ## Roll No.: EN231070055
# ## Batch: B
# ## Subject: AI&NN

# %% [markdown]
# <h4>Handwritten Digit Recognition (MNIST Dataset)-Implement a 3-layer neural network
# (Input → Hidden → Output) using Backpropagation.
#
# 1. Use Sigmoid, ReLU, or Tanh activation functions.
# 2. Train the network on the MNIST dataset to classify handwritten digits (0-9).
# 3. Optimize using Gradient Descent with Momentum or Adam Optimizer.</h4>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 28, 28)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 28, 28)

# %%
index=0
plt.imshow(x_train[index])
print(y_train[index])
# Out:
# 5

# %% [markdown]
# <h3>Relu Activation Function</h3>

# %%
model1 = Sequential([
    Flatten(input_shape=(28, 28)),     
    Dense(128, activation='relu'),    
    Dense(10, activation='softmax')])
# Out:
# C:\Users\Sakshi Jadhav\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model1.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model1.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9266 - loss: 0.2556 - val_accuracy: 0.9562 - val_loss: 0.1462
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9664 - loss: 0.1124 - val_accuracy: 0.9699 - val_loss: 0.0988
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9764 - loss: 0.0782 - val_accuracy: 0.9729 - val_loss: 0.0864
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9816 - loss: 0.0590 - val_accuracy: 0.9735 - val_loss: 0.0869
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9859 - loss: 0.0448 - val_accuracy: 0.9727 - val_loss: 0.0856

# %%
test_loss, test_acc = model1.evaluate(x_test, y_test)
print(f"\nTest Accuracy (Relu): {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9727 - loss: 0.0856
#
# Test Accuracy (Relu): 0.9727

# %%
plt.figure(figsize=(12,4))
    
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Loss - Relu')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
    
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Loss - Relu')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
    
plt.show()

# %% [markdown]
# <h3>Sigmoid Activation Function</h3>

# %%
model2 = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='sigmoid'),
    Dense(10, activation='softmax')])

# %%
model2.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history2 = model2.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.8988 - loss: 0.3975 - val_accuracy: 0.9333 - val_loss: 0.2285
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9446 - loss: 0.1930 - val_accuracy: 0.9537 - val_loss: 0.1572
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9597 - loss: 0.1410 - val_accuracy: 0.9605 - val_loss: 0.1345
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9690 - loss: 0.1083 - val_accuracy: 0.9670 - val_loss: 0.1126
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9752 - loss: 0.0867 - val_accuracy: 0.9712 - val_loss: 0.0969

# %%
test_loss, test_acc = model2.evaluate(x_test, y_test)
print(f"Test Accuracy (Sigmoid): {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9712 - loss: 0.0969
# Test Accuracy (Sigmoid): 0.9712

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history2.history['accuracy'], label='Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy - Sigmoid')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history2.history['loss'], label='Train Loss')
plt.plot(history2.history['val_loss'], label='Test Loss')
plt.title('Loss - Sigmoid')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# <h3>Tanh Activation Function</h3>

# %%
model3 = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='tanh'),
    Dense(10, activation='softmax')])

# %%
model3.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history3 = model3.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9189 - loss: 0.2845 - val_accuracy: 0.9532 - val_loss: 0.1637
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9599 - loss: 0.1382 - val_accuracy: 0.9666 - val_loss: 0.1135
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9727 - loss: 0.0937 - val_accuracy: 0.9692 - val_loss: 0.1030
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9800 - loss: 0.0697 - val_accuracy: 0.9734 - val_loss: 0.0832
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9846 - loss: 0.0523 - val_accuracy: 0.9737 - val_loss: 0.0838

# %%
test_loss, test_acc = model3.evaluate(x_test, y_test)
print(f"Test Accuracy (Tanh): {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9737 - loss: 0.0838
# Test Accuracy (Tanh): 0.9737

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history3.history['accuracy'], label='Train Accuracy')
plt.plot(history3.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy - Tanh')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history3.history['loss'], label='Train Loss')
plt.plot(history3.history['val_loss'], label='Test Loss')
plt.title('Loss - Tanh')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
